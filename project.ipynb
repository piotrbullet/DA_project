# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load all data
df_smoking_all = pd.read_csv('sales-of-cigarettes-per-adult-per-day.csv')
df_cancer_all = pd.read_csv('lung-cancer-death-rates-males.csv')
df_population = pd.read_csv('usa-population.csv')


# Select data for usa
df_smoking=df_smoking_all.loc[df_smoking_all['Code'] == "USA"]
df_cancer=df_cancer_all.loc[df_cancer_all['Code'] == "USA"]

# Rename column
df_smoking.rename(columns={df_smoking.columns[3]: "Sales"}, inplace=True)
df_cancer.rename(columns={df_cancer.columns[3]: "Death Rate"}, inplace=True)
# Out:
# /tmp/ipykernel_21777/3317025507.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_smoking.rename(columns={df_smoking.columns[3]: "Sales"}, inplace=True)
# /tmp/ipykernel_21777/3317025507.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cancer.rename(columns={df_cancer.columns[3]: "Death Rate"}, inplace=True)

# %%
df_population.head()
# Out:
#           Entity Code  Year  Population
# 0  United States  USA  1900    78763706
# 1  United States  USA  1901    80336086
# 2  United States  USA  1902    81949920
# 3  United States  USA  1903    83606240
# 4  United States  USA  1904    85296008

# %%
plt.plot(df_smoking["Year"], df_smoking["Sales"])
plt.title("Cigarette sales data")
plt.xlabel("Year")
plt.ylabel("Sales per adult per day")
plt.show()

plt.plot(df_cancer["Year"], df_cancer["Death Rate"])
plt.title("Lung cancer death rate")
plt.xlabel("Year")
plt.ylabel("Death Rate")
plt.show()

plt.plot(df_population["Year"], df_population["Population"])
plt.title("Population USA")
plt.xlabel("Year")
plt.ylabel("Population")
plt.show()
